# %% [markdown]
# ## Visualizing Earnings Based On College Majors
# Autor: Danilo de Sousa Lopes

# %% [markdown]
# Neste projeto guiado, iremos explorar como usar as funcionalidades de plotagem, juntamente com as técnicas forncidas pela biblioteca pandas em um conjunto de dados sobre os resultados do trabalho de alunos que se formaram na faculdade entre 2010 e 2012, gerados pela American Community Survey.

# %%
# importando as bibliotecas necessárias
import pandas as pd
import matplotlib.pyplot as plt

# comando mágico para que os gráficos sejam exibidos em linha
# %matplotlib inline

# lendo o conjunto de dados
recent_grads = pd.read_csv('recent-grads.csv')

# retorna a primeira linha formatada como uma tabela
print(recent_grads.iloc[0])

# retorna os 5 primeiros elementos de cada coluna do dataframe
print(recent_grads.head())

# retorna os 5 ultimos elementos de cada coluna do dataframe
print(recent_grads.tail())

# retorna uma resumo geral sobre todas as colunas numéricas
recent_grads.describe()
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
# descartando linhas com valores nulos
recent_grads = recent_grads.dropna()

# %% [markdown]
# ### Gráficos de Dispersão

# %%
# Sample_size vs Median
recent_grads.plot(x = 'Sample_size', y = 'Median', kind = 'scatter')

# %%
# Sample_size vs Unemployment_rate
recent_grads.plot(x = 'Sample_size', y = 'Unemployment_rate', kind = 'scatter')

# %%
# Full_time vs Median
recent_grads.plot(x = 'Full_time', y = 'Median', kind = 'scatter')

# %%
# ShareWomen vs Unemployment_rate
recent_grads.plot(x = 'ShareWomen', y = 'Unemployment_rate', kind = 'scatter')

# %%
# Men vs Median
recent_grads.plot(x = 'Men', y = 'Median', kind = 'scatter')

# %%
# Women vs Median
recent_grads.plot(x = 'Women', y = 'Median', kind = 'scatter')

# %% [markdown]
# ### Histogramas

# %%
# definindo as colunas necessárias
colunas = ["Sample_size", "Median", "Employed", "Full_time", 
           "ShareWomen", "Unemployment_rate", "Men", "Women"]

# gerando uma figura e definindo seu tamanho
fig = plt.figure(figsize = (5,20))

# realizando a interação entre o dataframe e nossa serie de colunas
for i in range(0,4):
    ax = fig.add_subplot(4, 1, i+1)
    ax = recent_grads[colunas[i]].plot(kind='hist', rot = 30)

# %% [markdown]
# ### Gráfico de Matriz de Dispersão
# Essa função faz parte do modúlo pandas.plotting e precisa ser importada separadamente.

# %%
# importando a função scatter matrix
from pandas.plotting import scatter_matrix

# criando uma gráfico de matriz de dispersão 2x2
scatter_matrix(recent_grads[['Sample_size', 'Median']], figsize = (8,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f5d322e2518>,
# ...
#       dtype=object)

# %%
# criando uma gráfico de matriz de dispersão 3x3
scatter_matrix(recent_grads[['Sample_size', 'Median', 'Unemployment_rate']], figsize = (12,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f5d306415c0>,
# ...
#       dtype=object)

# %% [markdown]
# ### Gráfico de Barras

# %%
# comparação curso vs porcentagens de mulheres das primeiras 10 linhas
recent_grads.head(10).plot.bar(x = 'Major', y = 'ShareWomen', legend = False)

# %%
# comparação curso vs porcentagens de mulheres das últimas 10 linhas
recent_grads.tail(10).plot.bar(x = 'Major', y = 'ShareWomen', legend = False)

# %%
# comparação curso vs taxa de desemprego das primeiras 10 linhas
recent_grads.head(10).plot.bar(x = 'Major', y = 'Unemployment_rate', legend = False)

# %%
# comparação cursos vs taxa de desemprego das últimas 10 linhas
recent_grads.tail(10).plot.bar(x = 'Major', y = 'Unemployment_rate', legend = False)
